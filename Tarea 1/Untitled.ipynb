# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataEA = np.loadtxt( 'ea.dat' )
dataEA[:3]
# Out:
# array([[0.0000e+00, 9.5218e+01],
#        [1.0000e-03, 9.4729e+01],
#        [2.0000e-03, 9.4241e+01]])

# %%
dataEI = np.loadtxt( 'ei.dat' )
dataEI[:3]
# Out:
# array([[ 0.   , 83.987],
#        [ 0.5  , 82.522],
#        [ 1.   , 80.569]])

# %%
plt.plot(dataEA[:,0], dataEA[:,1])

# %%
plt.plot(dataEI[:,0], dataEI[:,1])
